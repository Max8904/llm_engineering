# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

openai = OpenAI()

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="gpt-4o-mini", messages = [{"role":"user", "content":message}])
print(response.choices[0].message.content)

print(response)
# Out:
# Hello! Welcome! I'm glad to hear from you. How can I assist you today?
# ChatCompletion(id='chatcmpl-Bcwl8GMkL1wL7MctLlcqe5BD60yfU', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Hello! Welcome! I'm glad to hear from you. How can I assist you today?", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1748622034, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=CompletionUsage(completion_tokens=18, prompt_tokens=22, total_tokens=40, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"}

class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, "html.parser")

# %%
from bs4 import BeautifulSoup
import requests
import pprint as pp

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"}

url = "https://edwarddonner.com"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
pp.pprint(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>
# <!-- This site is optimized with the Yoast SEO plugin v25.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://edwarddonner.com/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Home - Edward Donner" property="og:title"/>
# <meta content="Homepage – this is a test of what happens to text on the homepage page" property="og:description"/>
# <meta content="https://edwarddonner.com/" property="og:url"/>
# <meta content="Edward Donner" property="og:site_name"/>
# ...

# %%
from IPython.display import display, Markdown

summary = \
"""
# Summary of Edward Donner\'s Website\n\nThe website serves as a personal and professional platform for Ed Donner, a co-founder and CTO of Nebula.io, a company focused on using AI to enhance talent recruitment. Ed shares his interests in coding, experimenting with Large Language Models (LLMs), DJing, electronic music production, and engaging with the tech community.\n\n### Notable Features\n- **Connect Four & Outsmart**: The site mentions two interactive features that appear to involve LLMs in competitive scenarios.\n  \n- **About Ed**: Provides insight into his background, previous ventures, and the impact of his work in the AI domain.\n  \n- **Recent Announcements**:\n  - **May 28, 2025**: Announcement of connecting courses aimed at becoming an LLM expert and leader.\n  - **May 18, 2025**: Information about the 2025 AI Executive Briefing.\n  - **April 21, 2025**: Details on "The Complete Agentic AI Engineering Course."\n  - **January 23, 2025**: Workshop announcement with hands-on resources related to LLMs and agents.\n\n### Social Connections\nThe site encourages visitors to connect with Ed via email and social media platforms such as LinkedIn and Twitter.
"""
display(Markdown(summary))
# Out:
# # Summary of Edward Donner's Website
#
# The website serves as a personal and professional platform for Ed Donner, a co-founder and CTO of Nebula.io, a company focused on using AI to enhance talent recruitment. Ed shares his interests in coding, experimenting with Large Language Models (LLMs), DJing, electronic music production, and engaging with the tech community.
#
# ### Notable Features
# - **Connect Four & Outsmart**: The site mentions two interactive features that appear to involve LLMs in competitive scenarios.
#
# - **About Ed**: Provides insight into his background, previous ventures, and the impact of his work in the AI domain.
#
# - **Recent Announcements**:
#   - **May 28, 2025**: Announcement of connecting courses aimed at becoming an LLM expert and leader.
#   - **May 18, 2025**: Information about the 2025 AI Executive Briefing.
#   - **April 21, 2025**: Details on "The Complete Agentic AI Engineering Course."
# ...

# %% [markdown]
# 註：
# 用 requests.post() 發送 HTTP POST 請求。
#     => json=payload 會自動把字典轉為 JSON 字串並附上正確 Content-Type。
# response.json() 把回傳結果轉為 Python 字典。

# %%
import requests
import pprint as pp

MODEL = "llama3.2"
messages = [
    {"role":"user", "content":"Describe some of the business applications of Generative AI"}
]

OLLAMA_API = "http://localhost:11434/api/chat"
payload = {
    "model":MODEL,
    "messages":messages,
    "stream": False
}
HEADERS = {"Content-Type":"application/json"}
response = requests.post(OLLAMA_API, json = payload, headers=HEADERS)

pp.pprint(response.json())
# print(response.json()["message"]["content"])
# Out:
# {'created_at': '2025-06-01T08:28:41.9327816Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 518,
#  'eval_duration': 12811052900,
#  'load_duration': 17346000,
#  'message': {'content': 'Generative AI has numerous business applications '
#                         'across various industries. Here are some examples:\n'
#                         '\n'
#                         '1. **Content Creation**: Generative AI can generate '
#                         'high-quality content, such as articles, social media '
#                         'posts, and product descriptions, saving time and '
#                         'resources for content creators.\n'
#                         '2. **Product Design**: Generative AI can be used to '
#                         'design new products, such as furniture, jewelry, or '
#                         'clothing, by generating 3D models and prototypes '
#                         'based on customer preferences and design trends.\n'
# ...

# %%
import ollama

MODEL = "llama3.2"
messages = [
    {"role":"user", "content":"Describe some of the business applications of Generative AI"}
]
response = ollama.chat(model = MODEL, messages = messages)

response.message.content
print(response["message"]["content"])
# Out:
# <class 'ollama._types.ChatResponse'>
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: Automate content creation, such as blog posts, social media posts, product descriptions, and more. This can save time and resources for content teams.
# 2. **Marketing and Advertising**: Use generative AI to create personalized ads, product recommendations, and customer personas based on user behavior and preferences.
# 3. **Design and Product Development**: Generate 2D and 3D designs, prototypes, and concept art using generative AI algorithms, reducing the need for manual design and iteration.
# 4. **Image and Video Editing**: Automate image editing tasks such as resizing, cropping, and applying filters to create consistent visual branding across marketing materials.
# ...

# %%
from openai import OpenAI

ollama_via_openai = OpenAI(base_url = "http://localhost:11434/v1", api_key = "ollama")

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality, unique content such as:
#  * Blog posts and articles
#  * Social media posts and captions
#  * Product descriptions and e-commerce content
#  * Videos and animations
# 2. **Digital Marketing**: Generative AI can be used to:
#  * Create personalized customer emails and newsletters
#  * Generate product reviews and ratings
#  * Develop chatbot conversations for customer support
#  * Optimize ad copy for better conversions
# 3. **Product Design and Development**: Generative AI can help with:
#  * Designing 3D models and CAD files
#  * Generating architectural designs and blueprints
#  * Creating product prototypes and mockups
# 4. **Customer Experience**: Generative AI can create personalized customer experiences, such as:
#  * Virtual assistants (e.g., Alexa, Google Assistant)
# ...

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model = Model,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
        stream = True
    )

    response = ""
    display_handle = display(Markdown(""), display_id = True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("'''", "").replace("markdown", "")
        update_display(Markdown(response), display_id = display_handle.display_id)
