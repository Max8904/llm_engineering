# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %% [markdown]
# 註：
# 1. soup.find_all('a')
# => 使用 BeautifulSoup 把 HTML 中所有 `<a>` 標籤找出來（這些通常是超連結）。
# 2. link.get('href')
# => 從每個 `<a>` 標籤中取出 href 屬性）。
#     如果有 href，就回傳該值
#     如果沒有 href，會回傳 None（而不會報錯）
# => 每個 HTML 標籤（例如 `<a>`, `<div>`）被表示為一個 Tag 物件，而這個 Tag 物件的屬性像一個字典一樣，可以使用 .get() 來安全地取得屬性值。

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %% [markdown]
# 註：
# response_format={"type": "json_object"}
# => 指示模型輸出 JSON 格式而不是普通文字 (OpenAI 新增的功能（2024 年中後釋出）)

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-R1-0528',
#  '/deepseek-ai/DeepSeek-R1-0528-Qwen3-8B',
#  '/ResembleAI/chatterbox',
#  '/google/gemma-3n-E4B-it-litert-preview',
#  '/ByteDance-Seed/BAGEL-7B-MoT',
#  '/models',
#  '/spaces/ResembleAI/Chatterbox',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/wushuang98/Direct3D-S2-v1.0-demo',
#  '/spaces/NihalGazi/Text-To-Speech-Unlimited',
#  '/spaces',
#  '/datasets/open-r1/Mixture-of-Thoughts',
#  '/datasets/yandex/yambda',
#  '/datasets/MiniMaxAI/SynLogic',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/cognitivecomputations/china-refusals',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 5 days ago
# •
# 47.9k
# •
# 1.67k
# deepseek-ai/DeepSeek-R1-0528-Qwen3-8B
# Updated
# 5 days ago
# •
# 72.6k
# •
# 607
# ResembleAI/chatterbox
# Updated
# 4 days ago
# •
# 528
# google/gemma-3n-E4B-it-litert-preview
# Updated
# 8 days ago
# •
# 834
# ByteDance-Seed/BAGEL-7B-MoT
# Updated
# 12 days ago
# •
# 8.73k
# •
# 932
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 619
# 619
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# 7.61k
# 7.61k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 399
# 399
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# 245
# 245
# Direct3D S2 V1.0 Demo
# 💻
# Generate 3D models from text descriptions
# Running
# 350
# 350
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# open-r1/Mixture-of-Thoughts
# Updated
# 8 days ago
# •
# 17.8k
# •
# 174
# yandex/yambda
# Updated
# about 3 hours ago
# •
# 14.7k
# •
# 105
# MiniMaxAI/SynLogic
# Updated
# about 10 hours ago
# •
# 440
# •
# 63
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 18.4k
# •
# 7.83k
# cognitivecomputations/china-refusals
# Updated
# 9 days ago
# •
# 479
# •
# 37
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 764 models
# •
# 3.35k followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.27k followers
# Amazon
# company
# •
# 20 models
# •
# 3.21k followers
# Google
# company
# •
# 997 models
# •
# 15.3k followers
# Intel
# company
# •
# 230 models
# •
# 2.6k followers
# Microsoft
# company
# •
# 381 models
# •
# 12.7k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 161 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 271 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,122
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,212
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,286
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,662
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,755
# Fast tokenizers optimized for research & production
# TRL
# 14,025
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,709
# State-of-the-art ML running directly in your browser
# smolagents
# 19,610
# Smol library to build great agents in Python
# PEFT
# 18,637
# Parameter-efficient finetuning for large language models
# Datasets
# 20,221
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,186
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,789
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 41,320
# AI & ML interests
# The AI community building the future.
# Recent Activity
# celinah
# updated
# a dataset
# 34 minutes ago
# huggingface/documentation-images
# frimelle
# new
# activity
# about 1 hour ago
# huggingface/policy-docs:
# [WIP] Updates on the EU policy docs
# frimelle
# new
# activity
# about 1 hour ago
# huggingface/policy-docs:
# Update EU policy responses
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 45
# Team members
# 217
# +183
# +170
# +149
# +139
# +119
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 237k
# •
# •
# 47
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 13.4M
# •
# •
# 699
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 7.84M
# •
# 192
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.81M
# •
# •
# 772
# spaces
# 27
# Sort:
# 		Recently updated
# pinned
# Running
# Hugging Face Fast
# 🏎
# Test your bandwidth speed
# huggingface
# 1 day ago
# pinned
# Running
# 89
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 178
# Inference Playground
# 🔋
# Set theme of the page based on user or system preferences
# huggingface
# 6 days ago
# Running
# 421
# AI Deadlines
# ⚡
# Manage project deadlines with AI assistance
# huggingface
# 14 days ago
# Running
# 9
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 19 days ago
# Running
# 128
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# Apr 16
# Expand
# 							27
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# Updated
# 10 days ago
# •
# 4.24k
# •
# 21
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 16
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 50.9k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 16
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 24.9k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 365
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 25.5k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 20
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 129k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 34 minutes ago
# •
# 52
# •
# 3.12M
# •
# 64
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.68k
# •
# 963
# •
# 23
# huggingface/policy-docs
# Viewer
# •
# Updated
# 4 days ago
# •
# 20
# •
# 1.42k
# •
# 11
# huggingface/electricity-production
# Viewer
# •
# Updated
# 12 days ago
# •
# 397
# •
# 93
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.76M
# •
# 43
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 569
# •
# 7
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 64
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 196
# huggingface/paper-central-data
# Viewer
# •
# Updated
# Jan 4
# •
# 124k
# •
# 131
# •
# 9
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# Dec 22, 2024
# •
# 5.03k
# •
# 48
# •
# 7
# Expand
# 							34
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 374 models
# •
# 27.8k followers
# Shopify
# Enterprise
# company
# •
# 473 followers
# AMD
# Enterprise
# company
# •
# 143 models
# •
# 1.57k followers
# Arm
# Enterprise
# company
# •
# 208 followers
# Qwen
# Enterprise
# company
# •
# 280 models
# •
# 33.3k followers
# Xsolla
# Enterprise
# company
# •
# 137 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 149 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 166 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.82k followers
# Aledade Inc
# Enterprise
# company
# •
# 72 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 161 followers
# MiniMax
# Enterprise
# company
# •
# 5 models
# •
# 706 followers
# Stability AI
# Enterprise
# company
# •
# 107 models
# •
# 24.4k followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 853 followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.27k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 529 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 612 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 271 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 284 followers
# Fidelity Investments
# Enterprise
# company
# •
# 147 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 69 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 426 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 64 followers
# LinkedIn
# Enterprise
# company
# •
# 60 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.02k followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 46.3k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 299 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 228 followers
# ServiceNow
# Enterprise
# company
# •
# 507 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 107 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 116 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 150 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.42k followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 332 followers
# Skywork
# Enterprise
# company
# •
# 40 models
# •
# 709 followers
# Liquid AI
# Enterprise
# company
# •
# 197 followers
# Mistral AI_
# Enterprise
# company
# •
# 28 models
# •
# 9k followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# 10× Private storage capacity
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 8× more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 8× usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2024
# •
# 34
# Community Articles
# view all
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 8 days ago
# •
# 40
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 602
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 6 days ago
# •
# 16
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 279
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 1 day ago
# •
# 12
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 1 day ago
# •
# 9
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# about 21 hours ago
# •
# 8
# Building an Open Ecosystem for Time Series Forecasting: Introducing TimesFM in Hugging Face
# By
# Nutanix
# and 1 other
# •
# 15 days ago
# •
# 16
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 327
# Common AI Model Formats
# By
# ngxson
# •
# Feb 27
# •
# 42
# OpenEvolve: An Open Source Implementation of Google DeepMind's AlphaEvolve
# By
# codelion
# •
# 14 days ago
# •
# 18
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 85
# Decoding Strategies in Large Language Models
# By
# mlabonne
# •
# Oct 29, 2024
# •
# 65
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 38
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 144
# PipelineRL
# By
# ServiceNow
# and 3 others
# •
# Apr 25
# •
# 24
# Falcon-Arabic: A Breakthrough in Arabic Language Models
# By
# tiiuae
# and 7 others
# •
# 13 days ago
# •
# 30
# AutoThink: Adaptive Reasoning for Large Language Models
# By
# codelion
# •
# 7 days ago
# •
# 4
# 🌙 Introducing **Moon**: Storytelling Generator Model
# By
# kulia-moon
# •
# 4 days ago
# •
# 4
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 254
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 35
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 18
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 117
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 31
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 125
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 20
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 109
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 26
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 66
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 405
# LeRobot Community Datasets: The “ImageNet” of Robotics — When and How?
# By
# danaaubakirova
# May 11, 2025
# •
# 52
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 143
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 37
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 49
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 8 days ago
# •
# 40
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 602
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 6 days ago
# •
# 16
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 279
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 1 day ago
# •
# 12
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 1 day ago
# •
# 9
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# about 21 hours ago
# •
# 8
# Building an Open Ecosystem for Time Series Forecasting: Introducing TimesFM in Hugging Face
# By
# Nutanix
# and 1 other
# •
# 15 days ago
# •
# 16
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 327
# Common AI Model Formats
# By
# ngxson
# •
# Feb 27
# •
# 42
# OpenEvolve: An Open Source Implementation of Google DeepMind's AlphaEvolve
# By
# codelion
# •
# 14 days ago
# •
# 18
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 85
# Decoding Strategies in Large Language Models
# By
# mlabonne
# •
# Oct 29, 2024
# •
# 65
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 38
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 144
# PipelineRL
# By
# ServiceNow
# and 3 others
# •
# Apr 25
# •
# 24
# Falcon-Arabic: A Breakthrough in Arabic Language Models
# By
# tiiuae
# and 7 others
# •
# 13 days ago
# •
# 30
# AutoThink: Adaptive Reasoning for Large Language Models
# By
# codelion
# •
# 7 days ago
# •
# 4
# 🌙 Introducing **Moon**: Storytelling Generator Model
# By
# kulia-moon
# •
# 4 days ago
# •
# 4
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 254
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Website Lags and freezes when browsing models
# Site Feedback
# 1
# 9
# June 3, 2025
# Seeking Guidance: How to Train a Vietnamese Real-Time Sales Chatbot That Fully Obeys a Prompt and Learns from Dialogues?
# Beginners
# 1
# 9
# June 3, 2025
# Why Do We Settle for Less?
# Models
# 1
# 7
# June 3, 2025
# Recursive Prompting
# Research
# 0
# 13
# June 3, 2025
# How to download a dataset with excel files?
# 🤗Datasets
# 1
# 15
# June 2, 2025
# Incompatibility Between smolagents and OpenAI API Due to additional_args
# Beginners
# 1
# 9
# June 3, 2025
# How can LLMs be fine-tuned for specialized domain knowledge?
# 🤗Transformers
# 2
# 187
# June 3, 2025
# Model Tuning and Re-Tuning Problems
# Models
# 1
# 16
# June 2, 2025
# Request for comments: Simple Universal Prompting System
# Research
# 0
# 14
# June 2, 2025
# Ajay Hinduja Geneva, Switzerland : How can I build a travel chatbot using Hugging Face transformers?
# Beginners
# 1
# 16
# June 2, 2025
# Implementing Triplet loss in Vit
# 🤗Transformers
# 1
# 7
# June 3, 2025
# Unresolved Billing Issue - $10 Verification Charges Not Reversed
# Site Feedback
# 1
# 15
# June 2, 2025
# How can I train a model to estimate pig weight from a photo? (agriculture/vision project)
# Beginners
# 1
# 22
# June 2, 2025
# AGENTS COURSE (gardio) - malicious file executed
# Course
# 1
# 11
# June 2, 2025
# 404 error when accessing google/gemma-2-27b-it chat completion endpoint
# Beginners
# 1
# 10
# June 2, 2025
# Fine tuning LLM for text classification -- error with SFTTrainer
# Intermediate
# 2
# 1362
# June 3, 2025
# Dario Schiraldi : Can I use chatbots to automate customer service?
# Beginners
# 1
# 8
# June 2, 2025
# Unable to extract the criteo/CriteoClickLogs dataset
# 🤗Datasets
# 4
# 14
# June 2, 2025
# HF auto train dataset load_metric error
# Beginners
# 31
# 34
# June 3, 2025
# A new solution to stabilize GPT-2 output structure — plug into your own trained models
# Beginners
# 4
# 10
# June 2, 2025
# Cant get into the AI Agents course discord
# Course
# 5
# 103
# June 2, 2025
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 41
# 172
# June 3, 2025
# This Python class offers a multiprocessing-powered Pool for efficiently collecting and managing experience replay data in reinforcement learning
# Show and Tell
# 0
# 7
# June 2, 2025
# 404 Error When Calling the Hugging Face Inference API via Dify
# Inference Endpoints on the Hub
# 3
# 23
# June 2, 2025
# Error fine tuning Donut model using LoRA
# Beginners
# 3
# 18
# June 3, 2025
# Facing issue building a simple RAG application using RetrievalQA
# Beginners
# 2
# 41
# May 30, 2025
# QuantumAccel – Symbolic Quantum Logic Gates for Efficient Computation
# Models
# 0
# 5
# June 2, 2025
# Restricting model download
# Models
# 0
# 11
# June 2, 2025
# Unable to push embeddings onto GPU
# Beginners
# 3
# 12
# June 3, 2025
# Processing input longer then model max input token length
# 🤗Datasets
# 3
# 11
# June 1, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 49.7k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 145k
# 29.2k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.2k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.2k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.6k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 541
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 317 repositories
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 13,937
# Apache-2.0
# 1,709
# 221
# 143
# Updated
# Jun 3, 2025
# smolagents
# Public
# 🤗 smolagents: a barebones library for agents that think in code.
# huggingface/smolagents’s past year of commit activity
# Python
# 19,615
# Apache-2.0
# 1,706
# 136
# (1 issue needs help)
# 100
# Updated
# Jun 3, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 145,123
# Apache-2.0
# 29,202
# 1,054
# (2 issues need help)
# 755
# Updated
# Jun 3, 2025
# text-embeddings-inference
# Public
# A blazing fast inference solution for text embeddings models
# huggingface/text-embeddings-inference’s past year of commit activity
# Rust
# 3,636
# Apache-2.0
# 265
# 113
# 10
# Updated
# Jun 3, 2025
# nanoVLM
# Public
# The simplest, fastest repository for training/finetuning small-sized VLMs.
# huggingface/nanoVLM’s past year of commit activity
# Python
# 3,092
# 252
# 17
# 7
# Updated
# Jun 3, 2025
# kernels
# Public
# Load compute kernels from the Hub
# huggingface/kernels’s past year of commit activity
# Python
# 140
# Apache-2.0
# 9
# 1
# 3
# Updated
# Jun 3, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 2,124
# MIT
# 413
# 106
# (5 issues need help)
# 55
# Updated
# Jun 3, 2025
# optimum-neuron
# Public
# Easy, fast and very cheap training and inference on AWS Trainium and Inferentia chips.
# huggingface/optimum-neuron’s past year of commit activity
# Jupyter Notebook
# 228
# Apache-2.0
# 76
# 11
# 10
# Updated
# Jun 3, 2025
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 10,186
# Apache-2.0
# 1,194
# 253
# 30
# Updated
# Jun 3, 2025
# optimum-intel
# Public
# 🤗 Optimum Intel: Accelerate inference with Intel optimization tools
# huggingface/optimum-intel’s past year of commit activity
# Jupyter Notebook
# 467
# Apache-2.0
# 131
# 28
# 19
# Updated
# Jun 3, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 547 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We‚Äôre on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at ü§ó
# 2h
# Report this post
# üîé There are over 1.5 million models on
# Hugging Face
# !
# But how do you find the right model, with the right parameter size, for your project?
#
# I‚Äôve just updated a semantic search prototype that lets you:
# ‚úÖ Filter models by parameter size (from 0-1B to 70B+)
# ‚úÖ Find models using AI-generated summaries
# ‚úÖ Explore trending and similar models effortlessly
#
# Whether you‚Äôre working with small models or need the firepower of a 70B+ model, this tool helps you find the best fit for your use case.
#
# üîó Try the prototype here:
# üëâ
# https://lnkd.in/eFSAC-CB
# Semantic Hugging Face Hub Search - a Hugging Face Space by librarian-bots
# huggingface.co
# 31
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ilyas Moutawwakil
# MLEng @HuggingFace ü§ó | MEng/MSc @CentraleSup√©lec üßëüéì
# 3w
# Edited
# Report this post
# Bored with long cold starts for torch.compile ? ü•∂
# Regional compilation was just merged into Accelerate and it massively cuts down compilation time while maintaining ALL the benefits üöÄ
#
# Torch.compile is one of @PyTorch‚Äôs most exciting features for performance optimization. But one pain point has always been its initial compile time, where waiting 10‚Äì20+ seconds on first run can be frustrating or even prohibitive üò≠
#
# That‚Äôs where regional compilation comes in ; Instead of compiling the entire model as one big graph, creating a huge optimization search space, we target and compile the repeating submodule (like the transformer block) once and reuse it through the compiler cache üß†
#
# This dramatically reduces compilation overhead while maintaining most of the performance üöÄ At model size >= 8B OR batch size >= 4, inference speedups are the SAME with 5-9x faster compilation, which means better UX for developers and more agility in iterative workflows.
#
# You can enable it right away in Accelerate through:
# TorchDynamoPlugin(use_regional_compilation=True)
# Or as a replacement for torch.compile:
# compiled_model = compile_regions(model, ...)
#
# Big thanks to
# R√©gis Pierrard
# ,
# Marc Sun
# and
# Sayak Paul
# for their reviews ü§ó
# And
# Animesh Jain
# for the great
# PyTorch
# tutorial that inspired this PR üôè
#
# üìäBenchmarks:
# https://lnkd.in/evJMKwpW
# üìúDocs:
# https://lnkd.in/etBxXxE2
# 179
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Yoni Gozlan
# ML Engineer @Hugging Face ü§ó
# 22h
# Edited
# Report this post
# üöÄ ColQwen2 is Now in
# Hugging Face
# Transformers!
#
# Great news for visual RAG workflows! ColQwen2, a powerful visual retriever, is now natively integrated into ü§ó Transformers. This means you can ditch those brittle OCR pipelines and retrieve documents directly from the visual space with just a few lines of code.
#
# ColQwen2 builds on the impactful ColPali work by
# Manuel Faysse
# ,
# Hugues Sibille
# , and
# Tony W.
# at
# ILLUIN Technology
# . ColQwen2 makes visual RAG smarter, simpler, and faster by offering key advantages:
# * Flexible: Handles arbitrary aspect ratios, so no more awkward square resizing.
# * Efficient: Supports dynamic resolution, leading to lighter multi-vector embeddings.
#
# Ready to try it out? Install the transformers model release today:
# pip install git+
# https://lnkd.in/e87TiGw4
# Hands-on Transformers-specific cookbooks are available to help you get started with embedding generation, retrieval scoring, and similarity map visualization.
# A big thank you to
# Tony W.
# for leading the integration process into Transformers!
#
# Dive deeper into ColQwen2 and its capabilities:
# ¬†* ü§óTransformers checkpoint:¬†
# https://lnkd.in/es_wVmdA
# ¬†* Model Details:
# https://lnkd.in/e4WfbYWt
# ¬†* Cookbooks:
# https://lnkd.in/eTXXJhWt
# ¬†* Paper:
# https://lnkd.in/e4cTHBm6
# 451
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ ü§ó Hugging Face
# 22h
# Report this post
# This summer is a great time to learn about agents and MCP at
# Hugging Face
# . We‚Äôve got a load of exciting events and courses. Here‚Äôs a round up of what we‚Äôre doing
#
# 1Ô∏è‚É£ - The MCP course is in its third week, with 3 units left:
# https://lnkd.in/eTuSr-Uh
# 2Ô∏è‚É£ - The
# Gradio
# team are hosting a global MCP and Agents hackathon with $500k in prizes:
# https://lnkd.in/ecVcTqsz
# 3Ô∏è‚É£ - The Classic Agents course is still available with interactive exercises and certificates:¬†
# https://lnkd.in/eiRYBPHd
# 4Ô∏è‚É£ - In Paris, Hugging Face is collaborating with
# Anthropic
# to deliver a super fun hackathon on Agents
# https://lu.ma/qpimrbx3
# Why not join in with one of all of these events to learn more about agents this summer. üåû
# 364
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,270 followers
# 1d
# Edited
# Report this post
# The biggest MCP hackathon keeps growing!
# Nebius
# joins us as a Partner in the Agents & MCP Hackathon
#
# Sponsor lineup:
# Anthropic
# ,
# Modal
# labs,
# Mistral AI
# ,
# SambaNova Systems
# ,
# Hyperbolic
# labs ,
# LlamaIndex
# ,
# Hugging Face
# , &
# Nebius
# AI Studio
#
# üöÄ~3k Participants
# üí∞$900k+ total Sponsorships
# 82
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,270 followers
# 1d
# Edited
# Report this post
# üßµTHREAD: 2500+ participants! Agents & MCP Hackathon has become the LARGEST AI development event of 2025.
#
# We started expecting 400 participants. We now have 2500+ registered and $700,000 in sponsorships... ü§Ø üëá
#
# 2/
# Anthropic
# stepped up as one of the main sponsors, recognizing this as THE definitive MCP ecosystem event...
#
# 3/
# Modal
# Labs made history with the most generous sponsorship - the largest single hackathon sponsorship ever...
# ü§ë $250 of GPU credits to every participant in the Hackathon!
#
# 4/
# Mistral AI
# ,
# SambaNova Systems
# ,
# Hyperbolic
# labs,
# LlamaIndex
# ,
# Hugging Face
# all confirmed...
# üí™ Bringing together cash prizes worth $16000+
# üí™ Special Category awards
# üí™ Strong technical Office Hours support, and
# üí™ More API credits üí∏
#
# 5/ 2500+ developers are together building the future of AI agents and MCP. Every serious player is here üòâ
#
# 6/ Registrations are closing June 2, 10 am UTC. History is being written. The MCP ecosystem is being created!
#
# Join thousands of developers building the Agentic and MCP future:
# https://lnkd.in/g7yp9HKG
# +3
# 87
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,270 followers
# 2d
# Edited
# Report this post
# üö® Attention! üí∏$16500 Cash Prizes
# Calling Serious Hackers: Agents & MCP Hackathon starts tonight!
#
# Our Sponsors are generously providing over $550,000+ in Free API and GPU Compute credits to participants:
# Anthropic
# ,
# Modal
# Labs,
# Hugging Face
# ,
# Mistral AI
# ,
# LlamaIndex
# ,
# SambaNova Systems
# , and
# Hyperbolic
# !
#
# You can still join here:
# https://lnkd.in/g7yp9HKG
# ‚Ä¶more
# 226
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,270 followers
# 1d
# Report this post
# Chain-of-zoom is trending!üöÄ
# Use this as an MCP server and build cool things in our Hackathon starting tonight.
#
# üëâ Join the biggest Agents/MCP Hackathon ever:
# https://lnkd.in/g7yp9HKG
# üëâ Explore the app:
# https://lnkd.in/gDkhSfrA
# ‚Ä¶more
# 140
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# 978,146 followers
# 1d
# Report this post
# üéôÔ∏è New to streaming or looking to level up? Check out StreamYard and get $10 discount! üòç
# https://lnkd.in/eRxAADGq
# Gradio x Agents x MCP Kickoff event
# www.linkedin.com
# 9
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,270 followers
# 2d
# Report this post
# Wild AI release of the week! üî•Chain-Of-Zoom: Zoom in to your image with extreme high resolution.
#
# Play with the app on
# Hugging Face
# :
# https://lnkd.in/gDkhSfrA
# ‚Ä¶more
# 167
# 9 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# ÿßŸÑÿπÿ±ÿ®Ÿäÿ© (Arabic)
# ‡¶¨‡¶æ‡¶Ç‡¶≤‡¶æ (Bangla)
# ƒåe≈°tina (Czech)
# Dansk (Danish)
# Deutsch (German)
# ŒïŒªŒªŒ∑ŒΩŒπŒ∫Œ¨ (Greek)
# English (English)
# Espa√±ol (Spanish)
# ŸÅÿßÿ±ÿ≥€å (Persian)
# Suomi (Finnish)
# Fran√ßais (French)
# ‡§π‡§ø‡§Ç‡§¶‡•Ä (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# ◊¢◊ë◊®◊ô◊™ (Hebrew)
# Êó•Êú¨Ë™û (Japanese)
# ÌïúÍµ≠Ïñ¥ (Korean)
# ‡§Æ‡§∞‡§æ‡§†‡•Ä (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ‡®™‡©∞‡®ú‡®æ‡®¨‡©Ä (Punjabi)
# Polski (Polish)
# Portugu√™s (Portuguese)
# Rom√¢nƒÉ (Romanian)
# –†—É—Å—Å–∫–∏–π (Russian)
# Svenska (Swedish)
# ‡∞§‡±Ü‡∞≤‡±Å‡∞ó‡±Å (Telugu)
# ‡∏†‡∏≤‡∏©‡∏≤‡πÑ‡∏ó‡∏¢ (Thai)
# Tagalog (Tagalog)
# T√ºrk√ße (Turkish)
# –£–∫—Ä–∞—ó–Ω—Å—å–∫–∞ (Ukrainian)
# Ti·∫øng Vi·ªát (Vietnamese)
# ÁÆÄ‰Ωì‰∏≠Êñá (Chinese (Simplified))
# Ê≠£È´î‰∏≠Êñá (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don‚Äôt have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\n5 days ago\n•\n47.9k\n•\n1.67k\ndeepseek-ai/DeepSeek-R1-0528-Qwen3-8B\nUpdated\n5 days ago\n•\n72.6k\n•\n607\nResembleAI/chatterbox\nUpdated\n4 days ago\n•\n528\ngoogle/gemma-3n-E4B-it-litert-preview\nUpdated\n8 days ago\n•\n836\nByteDance-Seed/BAGEL-7B-MoT\nUpdated\n12 days ago\n•\n8.73k\n•\n933\nBrowse 1M+ models\nSpaces\nRunning\non\nZero\n621\n621\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nRunning\n7.61k\n7.61k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n400\n400\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\n245\n245\nDirect3D S2 V1.0 Demo\n💻\nGenerate 3D models from text descriptions\nRunning\n350\n350\nRealistic Text To Speech Unlimited\n🔥\nFree Text-To-Speech generator with Emotion control (OpenAI)\nBrowse 400k+ applications\nDatasets\nopen-r1/Mixture-of-Thoughts\nUpdated\n8 days ago\n•\n20.7k\n•\n175\nyandex/yambda\nUpdated\nabout 3 hours ago\n•\n18.7k\n•\n106\nMiniMaxAI/SynLogic\nUpdated\nabout 11 hours ago\n•\n540\n•\n63\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n18.4k\n•\n7.83k\ncognitivecomputations/china-refusals\nUpdated\n9 days ago\n•\n556\n•\n37\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n764 models\n•\n3.35k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.15k models\n•\n6.27k followers\nAmazon\ncompany\n•\n20 models\n•\n3.21k followers\nGoogle\ncompany\n•\n997 models\n•\n15.3k followers\nIntel\ncompany\n•\n230 models\n•\n2.6k followers\nMicrosoft\ncompany\n•\n381 models\n•\n12.7k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n161 followers\nWriter\nEnterprise\ncompany\n•\n22 models\n•\n271 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,124\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,212\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,286\nSafe way to store/distribute neural network weights\nHub Python Library\n2,662\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,755\nFast tokenizers optimized for research & production\nTRL\n14,026\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,709\nState-of-the-art ML running directly in your browser\nsmolagents\n19,615\nSmol library to build great agents in Python\nPEFT\n18,639\nParameter-efficient finetuning for large language models\nDatasets\n20,221\nAccess & share datasets f ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face: The AI Community Building the Future
#
# ## About Us
# Hugging Face is a collaborative platform designed for the machine learning community, enabling individuals and organizations to create, discover, and share models, datasets, and applications. Our mission is to democratize AI and foster an inclusive environment where innovation thrives. With over 1 million models and 250,000 datasets available, we provide a robust foundation for collaboration in advancing artificial intelligence.
#
# ## Our Offerings
# - **Models**: Access a diverse library of state-of-the-art models across various modalities including text, image, video, audio, and even 3D.
# - **Datasets**: Browse through a vast collection of datasets tailored for different machine learning tasks.
# - **Spaces**: Utilize our hosting platform to run applications and collaborate with others in real-time.
# - **Enterprise Solutions**: Tailored solutions with enterprise-grade security, dedicated support, and the ability to deploy optimized Inference Endpoints.
#
# ## Customers
# More than 50,000 organizations, including industry leaders such as Google, Microsoft, Amazon, and Meta, rely on Hugging Face for their machine learning needs. Our platform serves as a crucial tool for researchers, developers, and enterprises aiming to harness the power of AI.
#
# ## Company Culture
# At Hugging Face, we value community collaboration and continuous learning. Our culture fosters innovation, inclusivity, and respect. We strive to create an environment where every individual can contribute meaningfully while enhancing their skills and knowledge in AI and machine learning.
#
# ## Careers
# Join our dynamic team dedicated to shaping the future of AI! We are constantly on the lookout for passionate individuals who want to make a difference in the tech landscape. We offer a variety of roles across different domains, catering to various skills and experiences. Explore current career opportunities and become part of our journey to revolutionize AI.
#
# ## Get In Touch
# Ready to collaborate or learn more about what we offer? Visit our website to explore, sign up, or reach out to us at:
#
# [Hugging Face](https://huggingface.co)
#
# Together, let's build the future of AI!
#
# ---
#
# ### Connect with Us
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/hugging-face)
# - [Discord](https://huggingface.co/discord)
#
# ---
#
# **Hugging Face: Your partner in AI innovation!**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %% [markdown]
# 註：
# 1. stream=True
# => 啟用串流模式，也就是讓模型一邊生成一邊傳回（適合長文）
# 2. display_handle
# => 建立一個可更新的顯示區塊（在 Jupyter Notebook 裡），初始為空的 Markdown 顯示。
#     display_id=True
#     => 它告訴 display()：「請為這次顯示建立一個唯一的 ID，這樣我之後可以用這個 ID 來更新這個顯示區塊，而不是再開一個新的」。
# 3. for chunk in stream
# => stream 是一個可迭代的生成器
# 4. chunk.choices[0].delta.content or ''
#     delta.content => 模型目前新生成的一小段文字（可能是一個字、詞或標點）。有時 delta 沒有 content，僅包含角色（role）或其他資訊。
#     or '' => 這裡的 or '' 是 Python 中常見的一種簡潔寫法。如果值是有效的內容（非空、非 None），就使用它；否則就改用空字串 ''。
# 6. update_display
# => 用來更新一個已經存在的輸出區塊，用來即時更新 Markdown 顯示
#     display_id => 使用剛剛建立的區塊 ID 來更新內容（不會產生新區塊）

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face!
# ### The AI Community Building the Future
#
# At Hugging Face, we are dedicated to creating a collaborative environment for developers, researchers, and companies interested in artificial intelligence (AI). Our platform offers an extensive library of models, datasets, and applications, making it the go-to destination for the machine learning community.
#
# ---
#
# ## Our Offerings
#
# - **Models**: Access over **1 million models** ranging from natural language processing to computer vision. Our community regularly contributes and updates models to ensure the state-of-the-art technology is available for everyone.
#
# - **Datasets**: Browse through **250,000+ datasets** designed for various machine learning tasks. Our platform allows users to upload and share their datasets for greater collaborative potential.
#
# - **Spaces**: Launch and showcase ML applications with **400k+ AI applications** running on our Spaces platform, facilitating real-time collaboration and experimentation.
#
# ---
#
# ## Who We Serve
# With over **50,000 organizations** utilizing Hugging Face, our diverse clientele includes notable names like:
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **AI at Meta**
# - **Intel**
#
# Whether you’re a startup, a research institution, or an enterprise, Hugging Face provides tailored solutions to meet your AI needs.
#
# ---
#
# ## Join Our Community
#
# At Hugging Face, we believe in the power of collaboration. Our vibrant community consists of passionate individuals contributing to the open-source ecosystem. Whether you're looking to contribute, seek help, or share your projects, our platform is the perfect place for you.
#
# ### Company Culture
# We pride ourselves on fostering an inclusive and innovative company culture. Collaboration and diversity are paramount; our team consists of individuals from various backgrounds who bring unique perspectives to the table. At Hugging Face, learning and growth are encouraged, and every team member is valued for their contributions.
#
# ---
#
# ## Career Opportunities
# Join the Hugging Face family! We are constantly on the lookout for talented individuals who share our passion for artificial intelligence. Our career opportunities span various fields, including engineering, product management, community engagement, and more.
#
# Interested candidates can explore current job openings on our website and take the first step towards an exciting career that shapes the future of AI.
#
# ---
#
# ## Accelerate Your ML Projects
#
# For organizations, we offer **paid Compute** and **Enterprise solutions** designed to enhance your machine learning projects with enterprise-grade security, access controls, and dedicated support.
#
# - **Compute Plans** start at **$0.60/hour** for GPU resources.
# - **Enterprise Plans** begin at **$20/user/month**.
#
# Our focus is on helping you move faster and more efficiently in your AI and ML initiatives.
#
# ---
#
# ### Connect with Us
# For more information, visit us at [Hugging Face](https://huggingface.co) and join us on our journey toward building the future of AI. Let’s innovate together!
#
# ---
#
# *Transforming AI collaboration, one model at a time.*

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
